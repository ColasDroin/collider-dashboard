# %%
#################### Imports ####################

# Import plotting functions
import functions

#################### Load global variables ####################
path_config = "/afs/cern.ch/work/c/cdroin/private/example_DA_study/master_study/scans/opt_flathv_75_1500_withBB_chroma5_1p4_eol_bbb_2228/base_collider/xtrack_0000/config.yaml"

# Define a path to the collider object
path_collider = None

# Also get a path to the collider after beam-beam object
if path_collider is not None:
    path_collider_before_bb = path_collider.replace(".json", "_before_bb.json")
else:
    path_collider_before_bb = None

# Load the global variables for the final collider
# (if build_collider is True in above function, a collider object is stored in temp folder)
twiss_check_after_beam_beam, twiss_check_before_beam_beam = functions.initialize_both_twiss_checks(
    path_config,
    path_collider=path_collider,
    path_collider_before_bb=path_collider_before_bb,
    build_collider=True,
)

# Get the global variables after the beam-beam
(
    l_lumi_after_beam_beam,
    collider_after_beam_beam,
    tw_b1_after_beam_beam,
    df_sv_b1_after_beam_beam,
    df_tw_b1_after_beam_beam,
    tw_b2_after_beam_beam,
    df_sv_b2_after_beam_beam,
    df_tw_b2_after_beam_beam,
    df_elements_corrected_after_beam_beam,
    table_sv_b1_after_beam_beam,
    table_tw_b1_after_beam_beam,
    table_sv_b2_after_beam_beam,
    table_tw_b2_after_beam_beam,
) = functions.initialize_global_variables(twiss_check_after_beam_beam)
# Out:
# Done loading line from dict.
# Done loading line from dict.
# Done loading line from dict.
# Done loading line from dict.
# Found suitable prebuilt kernel `default_bb3d`.
# Found suitable prebuilt kernel `default_bb3d`.
# Found suitable prebuilt kernel `default_only_xtrack`.
# Found suitable prebuilt kernel `default_only_xtrack`.
# Correcting closed orbit
# Correcting IR1 left
# Matching: twiss call n. 13
#
# Correcting IR1 right
# Matching: twiss call n. 13
#
# Correcting IR5 left
# Matching: twiss call n. 13
#
# Correcting IR5 right
# Matching: twiss call n. 13
#
# Correcting IP1
# Matching: twiss call n. 21
#
# Correcting IP2
# Matching: twiss call n. 21
#
# Correcting IP5
# Matching: twiss call n. 21
#
# Correcting IP8
# Matching: twiss call n. 21
#
# Matching linear coupling
# Matching: twiss call n. 3
#
# Matching tune and chromaticity
# Matching: twiss call n. 13
#
# Correcting closed orbit
# Correcting IR1 left
# Matching: twiss call n. 13
#
# Correcting IR1 right
# Matching: twiss call n. 13
#
# Correcting IR5 left
# Matching: twiss call n. 13
#
# Correcting IR5 right
# Matching: twiss call n. 13
#
# Correcting IP1
# Matching: twiss call n. 21
#
# Correcting IP2
# Matching: twiss call n. 21
#
# Correcting IP5
# Matching: twiss call n. 21
#
# Correcting IP8
# Matching: twiss call n. 21
#
# Matching linear coupling
# Matching: twiss call n. 3
#
# Matching tune and chromaticity
# Matching: twiss call n. 13
#
#
#  --- Leveling in ip2 ---
# Matching: twiss call n. 31
#
#
#  --- Leveling in ip8 ---
# Matching: twiss call n. 37
#
# Correcting closed orbit
# Correcting IR1 left
# Matching: twiss call n. 13
#
# Correcting IR1 right
# Matching: twiss call n. 13
#
# Correcting IR5 left
# Matching: twiss call n. 13
#
# Correcting IR5 right
# Matching: twiss call n. 13
#
# Correcting IP1
# Matching: twiss call n. 21
#
# Correcting IP2
# Matching: twiss call n. 21
#
# Correcting IP5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /afs/cern.ch/work/c/cdroin/private/example_DA_study/miniconda/lib/python3.10/site-packages/numpy/core/fromnumeric.py:75, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      74 try:
# ---> 75     reduction = getattr(obj, method)
#      76 except AttributeError:
#
# AttributeError: 'list' object has no attribute 'prod'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 20
#      16     path_collider_before_bb = None
#      18 # Load the global variables for the final collider
#      19 # (if build_collider is True in above function, a collider object is stored in temp folder)
# ---> 20 twiss_check_after_beam_beam, twiss_check_before_beam_beam = functions.initialize_both_twiss_checks(
#      21     path_config,
#      22     path_collider=path_collider,
#      23     path_collider_before_bb=path_collider_before_bb,
#      24     build_collider=True,
#      25 )
#      27 # Get the global variables after the beam-beam
#      28 (
#      29     l_lumi_after_beam_beam,
#      30     collider_after_beam_beam,
#    (...)
#      41     table_tw_b2_after_beam_beam,
#      42 ) = functions.initialize_global_variables(twiss_check_after_beam_beam)
#
# File /afs/cern.ch/work/c/cdroin/private/dashboard/functions.py:36, in initialize_both_twiss_checks(path_config, path_collider, path_collider_before_bb, build_collider)
#      29     raise ValueError(
#      30         "If build_collider is True, path_collider and path_collider_before_bb must not be"
#      31         " provided. If you want to use a collider from a json file, set build_collider to"
#      32         " False."
#      33     )
#      35 # Build collider from config file
# ---> 36 build_collider = BuildCollider(path_config)
#      38 # Dump collider
#      39 path_collider, path_collider_before_bb = build_collider.dump_collider(
#      40     prefix="temp/", dump_before_bb=True
#      41 )
#
# File /afs/cern.ch/work/c/cdroin/private/dashboard/modules/twiss_check/twiss_check.py:29, in BuildCollider.__init__(self, path_configuration, save_collider_before_bb)
#      26 self.correct_configuration()
#      28 # Load and tune collider
# ---> 29 self.collider, self.collider_before_bb = self.load_and_tune_collider(
#      30     save_collider_before_bb
#      31 )
#
# File /afs/cern.ch/work/c/cdroin/private/dashboard/modules/twiss_check/twiss_check.py:78, in BuildCollider.load_and_tune_collider(self, save_collider_before_bb)
#      76 # Build collider
#      77 if save_collider_before_bb:
# ---> 78     collider, _, collider_before_bb = configure_and_track.configure_collider(
#      79         self.configuration["config_simulation"],
#      80         self.configuration["config_collider"],
#      81         save_collider=False,
#      82         return_collider_before_bb=save_collider_before_bb,
#      83     )
#      84 else:
#      85     collider, _ = configure_and_track.configure_collider(
#      86         self.configuration["config_simulation"],
#      87         self.configuration["config_collider"],
#      88         save_collider=False,
#      89         return_collider_before_bb=save_collider_before_bb,
#      90     )
#
# File /afs/cern.ch/work/c/cdroin/private/example_DA_study/master_study/scans/opt_flathv_75_1500_withBB_chroma5_1p4_eol_bbb_2228/base_collider/xtrack_0000/2_configure_and_track.py:315, in configure_collider(config_sim, config_collider, skip_beam_beam, save_collider, return_collider_before_bb)
#     312 collider = add_linear_coupling(conf_knobs_and_tuning, collider)
#     314 # Rematch tune and chromaticity
# --> 315 collider = match_tune_and_chroma(
#     316     collider, conf_knobs_and_tuning, match_linear_coupling_to_zero=False
#     317 )
#     319 # Assert that tune, chromaticity and linear coupling are correct one last time
#     320 assert_tune_chroma_coupling(collider, conf_knobs_and_tuning)
#
# File /afs/cern.ch/work/c/cdroin/private/example_DA_study/master_study/scans/opt_flathv_75_1500_withBB_chroma5_1p4_eol_bbb_2228/base_collider/xtrack_0000/2_configure_and_track.py:104, in match_tune_and_chroma(collider, conf_knobs_and_tuning, match_linear_coupling_to_zero)
#      95     knob_names = conf_knobs_and_tuning["knob_names"][line_name]
#      97     targets = {
#      98         "qx": conf_knobs_and_tuning["qx"][line_name],
#      99         "qy": conf_knobs_and_tuning["qy"][line_name],
#     100         "dqx": conf_knobs_and_tuning["dqx"][line_name],
#     101         "dqy": conf_knobs_and_tuning["dqy"][line_name],
#     102     }
# --> 104     xm.machine_tuning(
#     105         line=collider[line_name],
#     106         enable_closed_orbit_correction=True,
#     107         enable_linear_coupling_correction=match_linear_coupling_to_zero,
#     108         enable_tune_correction=True,
#     109         enable_chromaticity_correction=True,
#     110         knob_names=knob_names,
#     111         targets=targets,
#     112         line_co_ref=collider[line_name + "_co_ref"],
#     113         co_corr_config=conf_knobs_and_tuning["closed_orbit_correction"][line_name],
#     114     )
#     116 return collider
#
# File /afs/cern.ch/work/c/cdroin/private/example_DA_study/modules/xmask/xmask/tuning.py:25, in machine_tuning(line, enable_closed_orbit_correction, enable_linear_coupling_correction, enable_tune_correction, enable_chromaticity_correction, knob_names, targets, line_co_ref, co_corr_config, verbose)
#      22         with open(co_corr_config, 'r') as fid:
#      23             co_corr_config = json.load(fid)
# ---> 25     line.correct_closed_orbit(
#      26                             reference=line_co_ref,
#      27                             correction_config=co_corr_config)
#      29 if enable_linear_coupling_correction:
#      30     assert knob_names is not None
#
# File /afs/cern.ch/work/c/cdroin/private/example_DA_study/miniconda/lib/python3.10/site-packages/xtrack/line.py:1023, in Line.correct_closed_orbit(self, reference, correction_config, solver, verbose, restore_if_fail)
#     961 def correct_closed_orbit(self, reference, correction_config,
#     962                     solver=None, verbose=False, restore_if_fail=True):
#     964     """
#     965     Correct the closed orbit of the beamline through a set of local matches.
#     966
#    (...)
#    1019
#    1020     """
# -> 1023     closed_orbit_correction(self, reference, correction_config,
#    1024                             solver=solver, verbose=verbose,
#    1025                             restore_if_fail=restore_if_fail)
#
# File /afs/cern.ch/work/c/cdroin/private/example_DA_study/miniconda/lib/python3.10/site-packages/xtrack/match.py:287, in closed_orbit_correction(line, line_co_ref, correction_config, solver, verbose, restore_if_fail)
#     285 for corr_name, corr in correction_config.items():
#     286     _print('Correcting', corr_name)
# --> 287     with xt.line._temp_knobs(line, corr['ref_with_knobs']):
#     288         tw_ref = line_co_ref.twiss(method='4d', zeta0=0, delta0=0)
#     289     vary = [xt.Vary(vv, step=1e-9) for vv in corr['vary']]
#
# File /afs/cern.ch/work/c/cdroin/private/example_DA_study/miniconda/lib/python3.10/contextlib.py:142, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     140 if typ is None:
#     141     try:
# --> 142         next(self.gen)
#     143     except StopIteration:
#     144         return False
#
# File /afs/cern.ch/work/c/cdroin/private/example_DA_study/miniconda/lib/python3.10/site-packages/xtrack/line.py:2837, in _temp_knobs(line_or_trk, knobs)
#    2835 finally:
#    2836     for kk, vv in old_values.items():
# -> 2837         line_or_trk.vars[kk] = vv
#
# File /afs/cern.ch/work/c/cdroin/private/example_DA_study/modules/xdeps/xdeps/refs.py:289, in MutableRef.__setitem__(self, key, value)
#     287 def __setitem__(self, key, value):
#     288     ref = ItemRef(self, key, self._manager)
# --> 289     self._manager.set_value(ref, value)
#
# File /afs/cern.ch/work/c/cdroin/private/example_DA_study/modules/xdeps/xdeps/tasks.py:170, in Manager.set_value(self, ref, value)
#     168     value = value._get_value()  # to be updated
#     169 ref._set_value(value)
# --> 170 self._run_tasks(self.find_tasks(ref._get_dependencies()))
#
# File /afs/cern.ch/work/c/cdroin/private/example_DA_study/modules/xdeps/xdeps/tasks.py:175, in Manager._run_tasks(self, tasks)
#     173 for task in tasks:
#     174     logger.info("Run %s", task)
# --> 175     task.run()
#
# File /afs/cern.ch/work/c/cdroin/private/example_DA_study/modules/xdeps/xdeps/tasks.py:76, in ExprTask.run(self)
#      74 def run(self):
#      75     value = self.expr._get_value()
# ---> 76     self.taskid._set_value(value)
#
# File /afs/cern.ch/work/c/cdroin/private/example_DA_study/modules/xdeps/xdeps/refs.py:510, in ItemRef._set_value(self, value)
#     509 def _set_value(self, value):
# --> 510     owner = ARef._mk_value(self._owner)
#     511     item = ARef._mk_value(self._key)
#     512     owner[item] = value
#
# File /afs/cern.ch/work/c/cdroin/private/example_DA_study/modules/xdeps/xdeps/refs.py:106, in ARef._mk_value(value)
#     103 @staticmethod
#     104 def _mk_value(value):
#     105     if isinstance(value, ARef):
# --> 106         return value._get_value()
#     107     else:
#     108         return value
#
# File /afs/cern.ch/work/c/cdroin/private/example_DA_study/modules/xdeps/xdeps/refs.py:450, in AttrRef._get_value(self)
#     448 owner = ARef._mk_value(self._owner)
#     449 attr = ARef._mk_value(self._key)
# --> 450 return getattr(owner, attr)
#
# File /afs/cern.ch/work/c/cdroin/private/example_DA_study/miniconda/lib/python3.10/site-packages/xobjects/hybrid_class.py:33, in _FieldOfDressed.__get__(self, container, ContainerType)
#      31         return getattr(container._xobject, self.name).to_nplike()[:lim]
#      32     else:
# ---> 33         return getattr(container._xobject, self.name).to_nplike()
#      34 elif hasattr(container, "_dressed_" + self.name):
#      35     return getattr(container, "_dressed_" + self.name)
#
# File /afs/cern.ch/work/c/cdroin/private/example_DA_study/miniconda/lib/python3.10/site-packages/xobjects/array.py:626, in Array.to_nplike(self)
#     624 cshape = [shape[ii] for ii in self._order]
#     625 if hasattr(self._itemtype, "_dtype"):
# --> 626     arr = self._buffer.to_nplike(
#     627         self._offset + self._data_offset, self._itemtype._dtype, cshape
#     628     ).transpose(self._order)
#     629     assert arr.strides == self._strides
#     630     return arr
#
# File /afs/cern.ch/work/c/cdroin/private/example_DA_study/miniconda/lib/python3.10/site-packages/xobjects/context_cpu.py:680, in BufferNumpy.to_nplike(self, offset, dtype, shape)
#     678 def to_nplike(self, offset, dtype, shape):
#     679     """view in nplike"""
# --> 680     count = np.prod(shape)
#     681     # dtype=np.dtype(dtype)
#     682     # return self.buffer[offset:].view(dtype)[:count].reshape(*shape)
#     683     return np.frombuffer(
#     684         self.buffer, dtype=dtype, count=count, offset=offset
#     685     ).reshape(*shape)
#
# File <__array_function__ internals>:200, in prod(*args, **kwargs)
#
# File /afs/cern.ch/work/c/cdroin/private/example_DA_study/miniconda/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3076, in prod(a, axis, dtype, out, keepdims, initial, where)
#    2955 @array_function_dispatch(_prod_dispatcher)
#    2956 def prod(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    2957          initial=np._NoValue, where=np._NoValue):
#    2958     """
#    2959     Return the product of array elements over a given axis.
#    2960
#    (...)
#    3074     10
#    3075     """
# -> 3076     return _wrapreduction(a, np.multiply, 'prod', axis, dtype, out,
#    3077                           keepdims=keepdims, initial=initial, where=where)
#
# File /afs/cern.ch/work/c/cdroin/private/example_DA_study/miniconda/lib/python3.10/site-packages/numpy/core/fromnumeric.py:75, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      73 if type(obj) is not mu.ndarray:
#      74     try:
# ---> 75         reduction = getattr(obj, method)
#      76     except AttributeError:
#      77         pass
#
# KeyboardInterrupt:
